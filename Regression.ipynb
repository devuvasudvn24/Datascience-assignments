# %% [markdown]
# <a href="https://colab.research.google.com/github/devuvasudvn24/Datascience-assignments/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/winequality-red.csv')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corrmat = data.corr()
plt.subplots(figsize = (10,8))
sns.heatmap(corrmat, annot = True,vmin= -0.2, vmax = 0.9, cmap = 'Blues')
plt.show()

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = data.drop('quality', axis=1)
y = data['quality']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 803             7.7             0.560         0.08            2.50      0.114
# 124             7.8             0.500         0.17            1.60      0.082
# 350            10.7             0.670         0.22            2.70      0.107
# 682             8.5             0.460         0.31            2.25      0.078
# 1326            6.7             0.460         0.24            1.70      0.077
# ...             ...               ...          ...             ...        ...
# 1259            6.8             0.640         0.00            2.70      0.123
# 1295            6.6             0.630         0.00            4.30      0.093
# 1155            8.3             0.600         0.25            2.20      0.118
# 963             8.8             0.270         0.39            2.00      0.100
# 704             9.1             0.765         0.04            1.60      0.078
#
# ...

# %%
y_test
# Out:
# 803     6
# 124     5
# 350     6
# 682     5
# 1326    6
#        ..
# 1259    6
# 1295    5
# 1155    5
# 963     6
# 704     4
# Name: quality, Length: 320, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)
mse = mean_squared_error(y_test, pred)
r2 = r2_score(y_test, pred)

# %%
mse, r2
# Out:
# (0.39002514396395427, 0.403180341279623)

# %%
from sklearn.metrics import mean_absolute_error
mse = mean_absolute_error(y_test, pred)
print(mse)
# Out:
# 0.5035304415524375

# %%
plt.scatter(x['alcohol'], y, color = 'steelblue', label='Actual Quality')
plt.plot(x['alcohol'], model.predict(x), color='powderblue', label='Predicted Quality')

plt.title('Linear Regression: Alcohol vs Wine Quality')
plt.xlabel('Alcohol Content')
plt.ylabel('Wine Quality')
plt.show()
